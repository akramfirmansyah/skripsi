# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, mean_absolute_percentage_error

from xgboost import XGBRegressor, plot_importance

import pickle

plt.rcParams['figure.figsize'] = (15, 8)

# %%
data_dir = 'data'
model_dir = 'model'
base_name = 'humidity'

# %%
df = pd.read_csv(f'../data/{base_name}.csv')
df = df[:-1]
df.head()
# Out:
#    Unnamed: 0  result  table                          _start  \
# 0         NaN     NaN      0  2024-10-31T12:38:00.507464249Z
# 1         NaN     NaN      0  2024-10-31T12:38:00.507464249Z
# 2         NaN     NaN      0  2024-10-31T12:38:00.507464249Z
# 3         NaN     NaN      0  2024-10-31T12:38:00.507464249Z
# 4         NaN     NaN      0  2024-10-31T12:38:00.507464249Z
#
#                             _stop                 _time     _value    _field  \
# 0  2024-11-02T12:38:00.507464249Z  2024-11-01T10:21:00Z  99.050000  humidity
# 1  2024-11-02T12:38:00.507464249Z  2024-11-01T10:22:00Z  99.294444  humidity
# 2  2024-11-02T12:38:00.507464249Z  2024-11-01T10:23:00Z  99.525714  humidity
# 3  2024-11-02T12:38:00.507464249Z  2024-11-01T10:24:00Z  99.622857  humidity
# 4  2024-11-02T12:38:00.507464249Z  2024-11-01T10:25:00Z  99.145714  humidity
#
#   _measurement
# 0        first
# 1        first
# 2        first
# 3        first
# 4        first

# %%
features_selected = ['_time', '_value']

df = df[features_selected]
df.head()
# Out:
#                   _time     _value
# 0  2024-11-01T10:21:00Z  99.050000
# 1  2024-11-01T10:22:00Z  99.294444
# 2  2024-11-01T10:23:00Z  99.525714
# 3  2024-11-01T10:24:00Z  99.622857
# 4  2024-11-01T10:25:00Z  99.145714

# %%
df.rename(columns={'_time': 'datetime', '_value': f'{base_name}'}, inplace=True)

# %%
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df.set_index('datetime', inplace=True)

# %%
df = df.round({f'{base_name}': 2})
df.head(10)
# Out:
#                            humidity
# datetime
# 2024-11-01 10:21:00+00:00     99.05
# 2024-11-01 10:22:00+00:00     99.29
# 2024-11-01 10:23:00+00:00     99.53
# 2024-11-01 10:24:00+00:00     99.62
# 2024-11-01 10:25:00+00:00     99.15
# 2024-11-01 10:26:00+00:00     99.28
# 2024-11-01 10:27:00+00:00     99.18
# 2024-11-01 10:28:00+00:00     99.69
# 2024-11-01 10:29:00+00:00     99.66
# 2024-11-01 10:30:00+00:00     99.62

# %%
fig, ax = plt.subplots()
df.plot(ax=ax)
plt.xticks(rotation=15)
plt.show()

# %%
df.describe()
# Out:
#           humidity
# count  1576.000000
# mean     92.247855
# std       9.788731
# min      65.420000
# 25%      87.327500
# 50%      97.730000
# 75%      98.772500
# max     100.000000

# %%
def create_features(data):
    """
    Creates time series features from datetime index
    """
    data['date'] = data.index
    data['minute'] = data['date'].dt.minute
    data['hour'] = data['date'].dt.hour
    data['day'] = data['date'].dt.day
    data['month'] = data['date'].dt.month
    data['year'] = data['date'].dt.year
    data['dayofweek'] = data['date'].dt.dayofweek
    data['dayofyear'] = data['date'].dt.dayofyear
    data['quarter'] = data['date'].dt.quarter
    data['weekofyear'] = data['date'].dt.isocalendar().week

    data = data.drop(columns='date')
    
    return data

# %%
df_cf = create_features(df)
df_cf
# Out:
#                            humidity  minute  hour  day  month  year  \
# datetime
# 2024-11-01 10:21:00+00:00     99.05      21    10    1     11  2024
# 2024-11-01 10:22:00+00:00     99.29      22    10    1     11  2024
# 2024-11-01 10:23:00+00:00     99.53      23    10    1     11  2024
# 2024-11-01 10:24:00+00:00     99.62      24    10    1     11  2024
# 2024-11-01 10:25:00+00:00     99.15      25    10    1     11  2024
# ...                             ...     ...   ...  ...    ...   ...
# 2024-11-02 12:33:00+00:00     95.51      33    12    2     11  2024
# 2024-11-02 12:34:00+00:00     95.89      34    12    2     11  2024
# 2024-11-02 12:35:00+00:00     95.27      35    12    2     11  2024
# 2024-11-02 12:36:00+00:00     95.13      36    12    2     11  2024
# 2024-11-02 12:37:00+00:00     95.03      37    12    2     11  2024
#
#                            dayofweek  dayofyear  quarter  weekofyear
# datetime
# 2024-11-01 10:21:00+00:00          4        306        4          44
# 2024-11-01 10:22:00+00:00          4        306        4          44
# 2024-11-01 10:23:00+00:00          4        306        4          44
# 2024-11-01 10:24:00+00:00          4        306        4          44
# 2024-11-01 10:25:00+00:00          4        306        4          44
# ...                              ...        ...      ...         ...
# 2024-11-02 12:33:00+00:00          5        307        4          44
# 2024-11-02 12:34:00+00:00          5        307        4          44
# 2024-11-02 12:35:00+00:00          5        307        4          44
# 2024-11-02 12:36:00+00:00          5        307        4          44
# 2024-11-02 12:37:00+00:00          5        307        4          44
#
# [1576 rows x 10 columns]

# %%
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

df_cf.to_csv(path_or_buf=f"{data_dir}/ready_{base_name}.csv", index=False)

# %%
X, y = df_cf.drop(columns=f'{base_name}'), df_cf[f'{base_name}']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False)

print(f"Number data training \t: {len(y_train)}")
print(f"Number data testing \t: {len(y_test)}")
# Out:
# Number data training 	: 1182
# Number data testing 	: 394

# %%
fig, ax = plt.subplots()
y_train.plot(ax=ax)
y_test.plot(ax=ax)
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# Training

# %%
params_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth' : [3, 5, 7, 9],
    'subsample': [0.8, 0.9, 1.0],
    'n_estimators': [500, 1000, 1500],
}

# %%
grid_search = GridSearchCV(XGBRegressor(), params_grid, verbose=3, scoring='neg_root_mean_squared_error')
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8;, score=-19.420 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8;, score=-1.061 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8;, score=-1.335 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8;, score=-6.028 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.8;, score=-5.439 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9;, score=-19.416 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9;, score=-1.091 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9;, score=-1.356 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9;, score=-6.053 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.9;, score=-5.446 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1.0;, score=-19.426 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1.0;, score=-1.106 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1.0;, score=-1.366 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1.0;, score=-6.088 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=1.0;, score=-5.485 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8;, score=-19.259 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8;, score=-1.124 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8;, score=-1.378 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8;, score=-6.099 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.8;, score=-5.208 total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9;, score=-19.239 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9;, score=-1.168 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9;, score=-1.408 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.9;, score=-6.085 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=1000, subsample=0.
total time=   0.3s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=500, subsample=0.9;, score=-1.513 total time=   0.3s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=500, subsample=0.9;, score=-6.449 total time=   0.3s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=500, subsample=0.9;, score=-5.434 total time=   0.3s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=500, subsample=1.0;, score=-21.324 total time=   0.2s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=500, subsample=1.0;, score=-0.905 total time=   0.2s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=500, subsample=1.0;, score=-1.538 total time=   0.2s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=500, subsample=1.0;, score=-6.416 total time=   0.2s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=500, subsample=1.0;, score=-5.443 total time=   0.2s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=0.8;, score=-21.243 total time=   0.5s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=0.8;, score=-1.008 total time=   0.5s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=0.8;, score=-1.410 total time=   0.5s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=0.8;, score=-6.435 total time=   0.5s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=0.8;, score=-5.435 total time=   0.5s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=0.9;, score=-20.675 total time=   0.4s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=0.9;, score=-0.915 total time=   0.4s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=0.9;, score=-1.512 total time=   0.5s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=0.9;, score=-6.449 total time=   0.5s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=0.9;, score=-5.434 total time=   0.4s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=1.0;, score=-21.324 total time=   0.3s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=1.0;, score=-0.905 total time=   0.3s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=1.0;, score=-1.538 total time=   0.3s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=1.0;, score=-6.416 total time=   0.3s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=1000, subsample=1.0;, score=-5.443 total time=   0.2s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=0.8;, score=-21.244 total time=   0.6s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=0.8;, score=-1.008 total time=   0.6s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=0.8;, score=-1.410 total time=   0.6s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=0.8;, score=-6.435 total time=   0.6s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=0.8;, score=-5.435 total time=   0.6s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=0.9;, score=-20.675 total time=   0.5s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=0.9;, score=-0.915 total time=   0.5s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=0.9;, score=-1.512 total time=   0.5s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=0.9;, score=-6.449 total time=   0.5s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=0.9;, score=-5.434 total time=   0.5s
# [CV 1/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=1.0;, score=-21.324 total time=   0.4s
# [CV 2/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=1.0;, score=-0.905 total time=   0.3s
# [CV 3/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=1.0;, score=-1.538 total time=   0.4s
# [CV 4/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=1.0;, score=-6.416 total time=   0.3s
# [CV 5/5] END learning_rate=0.2, max_depth=9, n_estimators=1500, subsample=1.0;, score=-5.443 total time=   0.4s
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bi...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 7, 9],
#                          'n_estimators': [500, 1000, 1500],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='neg_root_mean_squared_error', verbose=3)

# %%
best_params_grid = grid_search.best_params_
best_params_grid, grid_search.best_score_
# Out:
# ({'learning_rate': 0.2,
#   'max_depth': 5,
#   'n_estimators': 1000,
#   'subsample': 0.9},
#  np.float64(-6.32843674672961))

# %%
model = XGBRegressor(**best_params_grid)

# %%
model.fit(X_train, y_train, verbose=True)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

pickle.dump(model, open(f"{model_dir}/XGBoost_{base_name}.pkl", "wb"))

# %%
model_load = pickle.load(open(f"{model_dir}/XGBoost_{base_name}.pkl", "rb"))

# %%
_ = plot_importance(model_load, height=0.5, grid=False)

# %%
y_test = pd.DataFrame(y_test)
y_test
# Out:
#                            humidity
# datetime
# 2024-11-02 06:03:00+00:00     78.88
# 2024-11-02 06:04:00+00:00     79.21
# 2024-11-02 06:05:00+00:00     79.90
# 2024-11-02 06:06:00+00:00     79.76
# 2024-11-02 06:07:00+00:00     80.54
# ...                             ...
# 2024-11-02 12:33:00+00:00     95.51
# 2024-11-02 12:34:00+00:00     95.89
# 2024-11-02 12:35:00+00:00     95.27
# 2024-11-02 12:36:00+00:00     95.13
# 2024-11-02 12:37:00+00:00     95.03
#
# [394 rows x 1 columns]

# %%
y_test['predict'] = model_load.predict(X_test)

# %%
fig, ax = plt.subplots()
y_test.plot(ax=ax)
ax.legend(['Actual', 'prediction'])
plt.show()

# %%
mae = mean_absolute_error(y_true=y_test[f'{base_name}'], y_pred=y_test['predict'])
mape = mean_absolute_percentage_error(y_true=y_test[f'{base_name}'], y_pred=y_test['predict'])
rmse = root_mean_squared_error(y_true=y_test[f'{base_name}'], y_pred=y_test['predict'])

print(f"MAE \t: {mae}")
print(f"MAPE \t: {(mape * 100).round(2)}%")
print(f"RMSE \t: {rmse}")
# Out:
# MAE 	: 7.481249170448574
# MAPE 	: 7.84%
# RMSE 	: 10.23510246435417
